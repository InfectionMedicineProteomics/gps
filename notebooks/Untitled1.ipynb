# %%
import pandas as pd

# %%
export_path = '/home/aaron/projects/gscorer/data/tric/input/Simon_S1608_084.tsv'

# %%
peak_groups = pd.read_csv(export_path, sep='\t')

# %%
threshold = 0.01

# %%
pass_treshold = peak_groups.loc[
    peak_groups['m_score'] <= threshold
].copy()

# %%
pass_treshold
# Out:
#         Unnamed: 0  transition_group_id           feature_id   exp_rt  \
# 0                0                    0  3169727466424309507  3352.63
# 1                5                    1  1760294332150652289  3911.19
# 3               15                    3   674465207355643077  2742.69
# 4               20                    4  1701675932242799505  3700.65
# 5               25                    5  7754802121773620217  4792.68
# ...            ...                  ...                  ...      ...
# 104212      520092               108883  1120544487644025373  3881.37
# 104213      520096               108884  7423882711347691422  2997.00
# 104214      520101               108885  5463353277864109867  2852.90
# 104215      520106               108886  7151410567686709151  4390.46
# 104217      520116               108888  6907076438115847965  3032.34
#
#         norm_rt    delta_rt        mz  charge  decoy        peptide_sequence  \
# ...
